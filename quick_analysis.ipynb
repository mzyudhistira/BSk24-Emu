# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import run_analysis
# Out:
# 2025-01-07 20:08:22.073071: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-07 20:08:22.097865: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-07 20:08:22.127258: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-07 20:08:22.136239: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-07 20:08:22.157744: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def analyse_varian_effect(varians, files):
    files.reverse()
    results = [run_analysis.analyse(file) for file in files]
    rms_dev = [result['rms_dev'] for result in results]
    std_diff = [result['std_diff'] for result in results]
    melted_mass_table = [result['melted_mass_table'] for result in results]

    output = {'rms_dev' : rms_dev, 'std_diff' : std_diff,
              'mmt':melted_mass_table} 

    return output

# %%
# All run file
run_exp_1to1 = ['Test 128 varians w 0.2% sample each on exp mass predict other 128 random samples.dat',
                'Test 64 varians w 0.2% sample each on exp mass predict other 64 random samples.dat',
                'Test 32 varians w 0.2% sample each on exp mass predict other 32 random samples.dat',
                'Test 16 varians w 0.2% sample each on exp mass predict other 16 random samples.dat',
                'Test 8 varians w 0.2% sample each on exp mass predict other 8 random samples.dat',
                'Test 4 varians w 0.2% sample each on exp mass predict other 4 random samples.dat',
                'Test 2 varians w 0.2% sample each on exp mass predict other 2 random samples.dat']

run_exp_1to3 = [
                'Test 128 varians w 0.2% sample each on exp mass predict 384 random samples.dat',
                'Test 64 varians w 0.2% sample each on exp mass predict 192 random samples.dat',
                'Test 32 varians w 0.2% sample each on exp mass predict 96 random samples.dat',
                'Test 16 varians w 0.2% sample each on exp mass predict 48 random samples.dat',
                'Test 8 varians w 0.2% sample each on exp mass predict 24 random samples.dat',
                'Test 4 varians w 0.2% sample each on exp mass predict 12 random samples.dat',
                'Test 2 varians w 0.2% sample each on exp mass predict 6 random samples.dat',
               ]

run_exp_1to4 = [
                'Test 128 varians w 0.2% sample each on exp mass predict 512 random samples.dat',
                'Test 64 varians w 0.2% sample each on exp mass predict 256 random samples.dat',
                'Test 32 varians w 0.2% sample each on exp mass predict 128 random samples.dat',
                'Test 16 varians w 0.2% sample each on exp mass predict 64 random samples.dat',
                'Test 8 varians w 0.2% sample each on exp mass predict 32 random samples.dat',
                'Test 4 varians w 0.2% sample each on exp mass predict 16 random samples.dat',
               ]

run_ext_1to16 = [
                 'Test 32 varians w 0.2% sample each on exp mass predict 512 random ext samples.dat',
                 'Test 16 varians w 0.2% sample each on exp mass predict 256 random ext samples.dat',
                 'Test 8 varians w 0.2% sample each on exp mass predict 128 random ext samples.dat',
                 'Test 4 varians w 0.2% sample each on exp mass predict 64 random ext samples.dat',
                 'Test 2 varians w 0.2% sample each on exp mass predict 32 random ext samples.dat',
                ]

run_ext_1to8 = [
                'Test 64 varians w 0.2% sample each on exp mass predict 512 random ext samples.dat',
                'Test 32 varians w 0.2% sample each on exp mass predict 256 random ext samples.dat',
                'Test 16 varians w 0.2% sample each on exp mass predict 128 random ext samples.dat',
                'Test 8 varians w 0.2% sample each on exp mass predict 64 random ext samples.dat',
                'Test 4 varians w 0.2% sample each on exp mass predict 32 random ext samples.dat',
                'Test 2 varians w 0.2% sample each on exp mass predict 16 random ext samples.dat'
               ]

run_ext_1to1 = [
                'Test 128 varians w 0.2% sample each on exp mass predict 128 random ext samples.dat',
                'Test 64 varians w 0.2% sample each on exp mass predict 64 random ext samples.dat',
                'Test 32 varians w 0.2% sample each on exp mass predict 32 random ext samples.dat',
                'Test 16 varians w 0.2% sample each on exp mass predict 16 random ext samples.dat',
                'Test 8 varians w 0.2% sample each on exp mass predict 8 random ext samples.dat',
                'Test 4 varians w 0.2% sample each on exp mass predict 4 random ext samples.dat'
               ]

run_ext_1to2 = [
                 'Test 128 varians w 0.2% sample each on exp mass predict 256 random ext samples.dat',
                 'Test 64 varians w 0.2% sample each on exp mass predict 128 random ext samples.dat',
                 'Test 32 varians w 0.2% sample each on exp mass predict 64 random ext samples.dat',
                 'Test 16 varians w 0.2% sample each on exp mass predict 32 random ext samples.dat',
                 'Test 8 varians w 0.2% sample each on exp mass predict 16 random ext samples.dat',
                 'Test 4 varians w 0.2% sample each on exp mass predict 8 random ext samples.dat',
                 'Test 2 varians w 0.2% sample each on exp mass predict 4 random ext samples.dat'
                ]

run_ext_1to4 = [
                'Test 128 varians w 0.2% sample each on exp mass predict 512 random ext samples.dat',
                'Test 64 varians w 0.2% sample each on exp mass predict 256 random ext samples.dat',
                'Test 32 varians w 0.2% sample each on exp mass predict 128 random ext samples.dat',
                'Test 16 varians w 0.2% sample each on exp mass predict 64 random ext samples.dat',
                'Test 8 varians w 0.2% sample each on exp mass predict 32 random ext samples.dat',
                'Test 4 varians w 0.2% sample each on exp mass predict 16 random ext samples.dat',
                'Test 2 varians w 0.2% sample each on exp mass predict 8 random ext samples.dat'
               ]

# %%
v1 = [2, 4, 8, 16, 32, 64, 128]
v2 = v1[:-1]
v3 = v1[:-2]
v4 = [1] + v1

tests2 = {
    'exp_1to1':{
        'file' : run_exp_1to1,
        'plot_name' : 'Train:Predict Ratio = 1:1',
        'varian' : v1
    },
    'exp_1to3':{
        'file' : run_exp_1to3,
        'plot_name' : 'Train:Predict Ratio = 1:3',
        'varian' : v1
    },
    'exp_1to4':{
        'file' : run_exp_1to4,
        'plot_name' : 'Train:Predict Ratio = 1:4',
        'varian' : v1[1:]
    }
}

tests = {
    'ext_1to1':{
        'file': run_ext_1to1,
        'plot_name': 'Train:Predict Ratio = 1:1',
        'varian' : v1[1:]
    },
    'ext_1to2':{
        'file': run_ext_1to2,
        'plot_name': 'Train:Predict Ratio = 1:2',
        'varian' : v1
    },
    'ext_1to4':{
        'file': run_ext_1to4,
        'plot_name': 'Train:Predict Ratio = 1:4',
        'varian' : v1
    },
    'ext_1to8':{
        'file': run_ext_1to8,
        'plot_name': 'Train:Predict Ratio = 1:8',
        'varian' : v2
    },
    'ext_1to16':{
        'file': run_ext_1to16,
        'plot_name': 'Train:Predict Ratio = 1:16',
        'varian' : v3
    },

}
print(tests)
for name, test in tests.items():
    test_name = test['file']
    print(test_name)
    test_varian = test['varian']
    test ['result'] = analyse_varian_effect(test_varian, test_name)

plt.figure(figsize=(8, 6))
for name, test in tests.items():
    plt.plot(test['varian'], test['result']['rms_dev'], label=test['plot_name'])

plt.xlabel('Number of Varians')
plt.ylabel('rms_dev (MeV)')
plt.legend()
# Out:
# {'ext_1to1': {'file': ['Test 128 varians w 0.2% sample each on exp mass predict 128 random ext samples.datTest 64 varians w 0.2% sample each on exp mass predict 64 random ext samples.datTest 32 varians w 0.2% sample each on exp mass predict 32 random ext samples.datTest 16 varians w 0.2% sample each on exp mass predict 16 random ext samples.datTest 8 varians w 0.2% sample each on exp mass predict 8 random ext samples.datTest 4 varians w 0.2% sample each on exp mass predict 4 random ext samples.dat'], 'plot_name': 'Train:Predict Ratio = 1:1', 'varian': [4, 8, 16, 32, 64, 128]}, 'ext_1to2': {'file': ['Test 128 varians w 0.2% sample each on exp mass predict 256 random ext samples.datTest 64 varians w 0.2% sample each on exp mass predict 128 random ext samples.datTest 32 varians w 0.2% sample each on exp mass predict 64 random ext samples.datTest 16 varians w 0.2% sample each on exp mass predict 32 random ext samples.datTest 8 varians w 0.2% sample each on exp mass predict 16 random ext samples.datTest 4 varians w 0.2% sample each on exp mass predict 8 random ext samples.datTest 2 varians w 0.2% sample each on exp mass predict 4 random ext samples.dat'], 'plot_name': 'Train:Predict Ratio = 1:2', 'varian': [2, 4, 8, 16, 32, 64, 128]}, 'ext_1to4': {'file': ['Test 128 varians w 0.2% sample each on exp mass predict 512 random ext samples.datTest 64 varians w 0.2% sample each on exp mass predict 256 random ext samples.datTest 32 varians w 0.2% sample each on exp mass predict 128 random ext samples.datTest 16 varians w 0.2% sample each on exp mass predict 64 random ext samples.datTest 8 varians w 0.2% sample each on exp mass predict 32 random ext samples.datTest 4 varians w 0.2% sample each on exp mass predict 16 random ext samples.datTest 2 varians w 0.2% sample each on exp mass predict 8 random ext samples.dat'], 'plot_name': 'Train:Predict Ratio = 1:4', 'varian': [2, 4, 8, 16, 32, 64, 128]}, 'ext_1to8': {'file': ['Test 64 varians w 0.2% sample each on exp mass predict 512 random ext samples.datTest 32 varians w 0.2% sample each on exp mass predict 256 random ext samples.datTest 16 varians w 0.2% sample each on exp mass predict 128 random ext samples.datTest 8 varians w 0.2% sample each on exp mass predict 64 random ext samples.datTest 4 varians w 0.2% sample each on exp mass predict 32 random ext samples.datTest 2 varians w 0.2% sample each on exp mass predict 16 random ext samples.dat'], 'plot_name': 'Train:Predict Ratio = 1:8', 'varian': [2, 4, 8, 16, 32, 64]}, 'ext_1to16': {'file': ['Test 32 varians w 0.2% sample each on exp mass predict 512 random ext samples.datTest 16 varians w 0.2% sample each on exp mass predict 256 random ext samples.datTest 8 varians w 0.2% sample each on exp mass predict 128 random ext samples.datTest 4 varians w 0.2% sample each on exp mass predict 64 random ext samples.datTest 2 varians w 0.2% sample each on exp mass predict 32 random ext samples.dat'], 'plot_name': 'Train:Predict Ratio = 1:16', 'varian': [2, 4, 8, 16, 32]}}
# ['Test 128 varians w 0.2% sample each on exp mass predict 128 random ext samples.datTest 64 varians w 0.2% sample each on exp mass predict 64 random ext samples.datTest 32 varians w 0.2% sample each on exp mass predict 32 random ext samples.datTest 16 varians w 0.2% sample each on exp mass predict 16 random ext samples.datTest 8 varians w 0.2% sample each on exp mass predict 8 random ext samples.datTest 4 varians w 0.2% sample each on exp mass predict 4 random ext samples.dat']
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[10], line 57
#      55     print(test_name)
#      56     test_varian = test['varian']
# ---> 57     test ['result'] = analyse_varian_effect(test_varian, test_name)
#      59 plt.figure(figsize=(8, 6))
#      60 for name, test in tests.items():
#
# Cell In[2], line 3, in analyse_varian_effect(varians, files)
#       1 def analyse_varian_effect(varians, files):
#       2     files.reverse()
# ----> 3     results = [run_analysis.analyse(file) for file in files]
#       4     rms_dev = [result['rms_dev'] for result in results]
#       5     std_diff = [result['std_diff'] for result in results]
#
# Cell In[2], line 3, in <listcomp>(.0)
#       1 def analyse_varian_effect(varians, files):
#       2     files.reverse()
# ----> 3     results = [run_analysis.analyse(file) for file in files]
#       4     rms_dev = [result['rms_dev'] for result in results]
#       5     std_diff = [result['std_diff'] for result in results]
#
# File /mnt/Data/2_Area_Learn/Master Degree/2 Area_Courses/Master Thesis/1_Project/4_BSk24_Emu/run_analysis.py:106, in analyse(mass_table_file)
#     105 def analyse(mass_table_file):
# --> 106     mass_table = pd.read_csv(DATA_DIR / 'output' / mass_table_file, sep=';')
#     107     melted_mass_table = melt_mass_table(mass_table)
#     109     rms_deviation = np.sqrt((mass_table['Difference']**2).mean())
#
# File /opt/miniconda3/envs/tf/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /opt/miniconda3/envs/tf/lib/python3.10/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File /opt/miniconda3/envs/tf/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File /opt/miniconda3/envs/tf/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File /opt/miniconda3/envs/tf/lib/python3.10/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# OSError: [Errno 36] File name too long: '/mnt/Data/2_Area_Learn/Master Degree/2 Area_Courses/Master Thesis/1_Project/4_BSk24_Emu/data/output/Test 128 varians w 0.2% sample each on exp mass predict 128 random ext samples.datTest 64 varians w 0.2% sample each on exp mass predict 64 random ext samples.datTest 32 varians w 0.2% sample each on exp mass predict 32 random ext samples.datTest 16 varians w 0.2% sample each on exp mass predict 16 random ext samples.datTest 8 varians w 0.2% sample each on exp mass predict 8 random ext samples.datTest 4 varians w 0.2% sample each on exp mass predict 4 random ext samples.dat'

# %%
plt.figure(figsize=(8, 6))
for name, test in tests.items():
    plt.plot(test['varian'], test['result']['std_diff'], label=test['plot_name'])

plt.xlabel('Number of Varians')
plt.ylabel('std_diff (MeV)')
plt.legend()

# %%
len(tests['exp_1to4']['result']['mmt'][-1])
run_analysis.plot_landscape(tests['exp_1to4']['result']['mmt'][-1])
# Out:
# (<Figure size 640x480 with 2 Axes>,
#  <Axes: xlabel='N', ylabel='Z'>,
#  <matplotlib.collections.PathCollection at 0x7fbcbb51de70>)
